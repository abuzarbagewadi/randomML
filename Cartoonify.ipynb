# %% [markdown]
# <a href="https://colab.research.google.com/github/abuzarbagewadi/randomML/blob/main/Cartoonify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("/DeepLearningCat.jfif")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY )
gray  = cv2.medianBlur(gray, 5)
edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 9, 9)

# %%
color = cv2.bilateralFilter(img, 20, 150, 150)
cartoon = cv2.bitwise_and(color, color, mask=edges)

# %%
from google.colab.patches import cv2_imshow

cv2_imshow(img)
cv2_imshow(edges)
cv2_imshow(cartoon)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x688 at 0x7F1C1B08EC18>
# <PIL.Image.Image image mode=L size=1000x688 at 0x7F1C1B08EAC8>
# <PIL.Image.Image image mode=RGB size=1000x688 at 0x7F1C1B08EC88>
